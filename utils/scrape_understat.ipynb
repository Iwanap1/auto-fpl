# %%
from understatapi import UnderstatClient

with UnderstatClient() as understat:
    team_match_data = understat.team(team="Manchester_United").get_match_data(season="2019")

# %%
# Out:
# [{'id': '1250',
#   'player_name': 'Mohamed Salah',
#   'games': '38',
#   'time': '3392',
#   'goals': '29',
#   'xG': '27.70626749098301',
#   'assists': '18',
#   'xA': '15.858334187418222',
#   'shots': '130',
#   'key_passes': '89',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Liverpool',
#   'npg': '20',
#   'npxG': '20.855747912079096',
#   'xGChain': '48.53588879853487',
#   'xGBuildup': '16.20675839856267'},
#  {'id': '5232',
#   'player_name': 'Alexander Isak',
#   'games': '34',
#   'time': '2822',
#   'goals': '23',
#   'xG': '22.356988068670034',
#   'assists': '6',
#   'xA': '5.44870379474014',
#   'shots': '99',
#   'key_passes': '42',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Newcastle United',
#   'npg': '19',
#   'npxG': '19.312312599271536',
#   'xGChain': '26.209551103413105',
#   'xGBuildup': '3.579237926751375'},
#  {'id': '8260',
#   'player_name': 'Erling Haaland',
# ...

# %%
understat.player(player='10864').get_shot_data()
# Out:
# [{'id': '494395',
#   'minute': '46',
#   'result': 'MissedShots',
#   'X': '0.9230000305175782',
#   'Y': '0.539000015258789',
#   'xG': '0.09617079794406891',
#   'player': 'Marcos Senesi',
#   'h_a': 'h',
#   'player_id': '10864',
#   'situation': 'FromCorner',
#   'season': '2022',
#   'shotType': 'Head',
#   'match_id': '18313',
#   'h_team': 'Bournemouth',
#   'a_team': 'Southampton',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2022-10-19 18:30:00',
#   'player_assisted': 'Lewis Cook',
#   'lastAction': 'Cross'},
#  {'id': '508578',
#   'minute': '29',
#   'result': 'Goal',
#   'X': '0.9780000305175781',
#   'Y': '0.45099998474121095',
#   'xG': '0.684535026550293',
#   'player': 'Marcos Senesi',
#   'h_a': 'h',
#   'player_id': '10864',
#   'situation': 'FromCorner',
#   'season': '2022',
#   'shotType': 'LeftFoot',
#   'match_id': '18423',
#   'h_team': 'Bournemouth',
#   'a_team': 'Newcastle United',
#   'h_goals': '1',
#   'a_goals': '1',
# ...

# %%
understat.match("11879").get_roster_data()
# Out:
# {'h': {'386500': {'id': '386500',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '546',
#    'team_id': '89',
#    'position': 'GK',
#    'player': 'David de Gea',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.21450400352478027',
#    'xGBuildup': '0.21450400352478027',
#    'positionOrder': '1'},
#   '386501': {'id': '386501',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '5584',
#    'team_id': '89',
#    'position': 'DR',
#    'player': 'Aaron Wan-Bissaka',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '4',
#    'assists': '0',
#    'xA': '0.4199950098991394',
#    'xGChain': '0.7041559815406799',
# ...
